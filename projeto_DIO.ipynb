# %%
import pandas as pd
df = pd.read_csv('ataques.csv')
df.head()
# Out:
#               Target  AKA                         description       sector  \
# 0             Kaseya  NaN                                  NaN        tech
# 1     Salvation Army  NaN                                  NaN         NaN
# 2       Grupo Fleury  NaN  Brazil's largest diagnostic company  healthcare
# 3      City of Liege  NaN                                  NaN  government
# 4  Lucky Star Casino  NaN                                  NaN         NaN
#
#    organisation size 1,5,10,25,100,300   revenue $USD million      cost  \
# 0                                   300                  300.0       70
# 1                                     1                    NaN  unknown
# 2                                    10                  686.0  unknown
# 3                                     1                    NaN  unknown
# 4                                     1                    9.0  unknown
#
#    ransom cost data note ransom paid  ...  revenue as of  no of employees  \
# ...

# %%
df.fillna(value='Sem informação')

# %%
df[df['sector']== "mixed"]
# Out:
#                    Target                          AKA  \
# 336            "WannaCry"                          NaN
# 338  "Petya" & "NotPetya"    Multiple systems globally
# 339           "BadRabbit"  Russian & Ukrainian systems
# 352        "TeslaCrypt 2"           Multiple computers
# 353          "TeslaCrypt"             Multiple systems
# 355         Apple devices                          NaN
# 356          "Cryptowall"             Multiple systems
# 357        "Cryptolocker"              250,000 systems
#
#                  description  sector  organisation size 1,5,10,25,100,300   \
# 336  230,000 systems globally  mixed                                   300
# 338                       NaN  mixed                                   100
# 339                       NaN  mixed                                   100
# 352                       NaN  mixed                                     5
# 353                       NaN  mixed                                     5
# ...

# %%
df.to_json('arquivo.json')
